# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# (**Ugonna Dike**)
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because of my ability to analyze and interpret data as well as the wealth of diverse opportunities presented in this ever growing field*

# %% [markdown]
# ### My code is supposed to add all numbers from 1 to 9

# %%
print(1 + 2 + 3 + 4 + 5 + 6 + 7 + 8 + 9)
# Out:
# 45

# %% [markdown]
# Household items in table
# _________________________
#
# + Non-Edible
# 1. Dish soap
# 2. Detergent
# 3. Body Lotion
#
# + Edible
# 1. Eggs
# 2. Bacon
# 3. Cheese
#
# > This is a list of household items with quantities and costs.
# > This does not include milk.
#
# Quote break
#
# > Will buy milk later.
